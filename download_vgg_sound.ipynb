# %% [markdown]
# # notebook contains code and comment for downloading vggset dataset, re-download missing downloads, postprocess raw audio files

# %%
import os
from glob import glob
from tqdm.notebook import tqdm
import pandas as pd
import json

#import youtube_dl
import yt_dlp as youtube_dl
import librosa
from pydub import AudioSegment

import concurrent.futures
import threading

# %%
VGGSOUND_DATASET_PATH = "./vggsound/"
MP3_FILE_ROOT_PATH = "./vggsound_tmp"
VGGSOUND_METADATA_PATH = "./vggsound_meta_data.json"

os.makedirs(VGGSOUND_DATASET_PATH, exist_ok=True)

# vggsound.csv : https://www.robots.ox.ac.uk/~vgg/data/vggsound/
vggsound_data = pd.read_csv("vggsound.csv", names=["YouTube ID", "start seconds", "label", "train/test split"])

with open(VGGSOUND_METADATA_PATH, "r") as fp :
    vggsound_meta_data = json.load(fp)

# %% [markdown]
# ## set yt_dlp options

# %%
ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '320',
    }],
    'outtmpl': os.path.join(MP3_FILE_ROOT_PATH, "%(id)s.%(ext)s"),
    'quiet':True,
    'external_downloader_args': ['-loglevel', 'panic']
}
slink = "https://www.youtube.com/watch?v="

vggsound_data["url"] = slink + vggsound_data["YouTube ID"]

vggsound_data
# Out:
#          YouTube ID  start seconds                  label train/test split  \
# 0       ---g-f_I2yQ              1        people marching             test
# 1       --0PQM4-hqg             30     waterfall burbling            train
# 2       --56QUhyDQM            185         playing tennis            train
# 3       --5OkAjCI7g             40  people belly laughing            train
# 4       --8puiAGLhs             30    car engine starting            train
# ...             ...            ...                    ...              ...
# 199462  zzsUhaDSqzI            145         lathe spinning            train
# 199463  zztvx3WUBss             30       people shuffling            train
# 199464  zzvCPtdNxNo             68    civil defense siren             test
# 199465  zzvSVusPPgM             30       chicken clucking            train
# 199466  zzwbG0dHLhI            150            lawn mowing            train
#
#                                                 url
# 0       https://www.youtube.com/watch?v=---g-f_I2yQ
# 1       https://www.youtube.com/watch?v=--0PQM4-hqg
# 2       https://www.youtube.com/watch?v=--56QUhyDQM
# 3       https://www.youtube.com/watch?v=--5OkAjCI7g
# 4       https://www.youtube.com/watch?v=--8puiAGLhs
# ...                                             ...
# 199462  https://www.youtube.com/watch?v=zzsUhaDSqzI
# 199463  https://www.youtube.com/watch?v=zztvx3WUBss
# 199464  https://www.youtube.com/watch?v=zzvCPtdNxNo
# 199465  https://www.youtube.com/watch?v=zzvSVusPPgM
# 199466  https://www.youtube.com/watch?v=zzwbG0dHLhI
#
# [199467 rows x 5 columns]

# %% [markdown]
# ## define function for download raw audio

# %%
def download_video(url, opt) :
    with youtube_dl.YoutubeDL(opt) as ydl :
        try :
            ydl.download([url])
            return {"url": url, "status":True}
        except Exception as e :
            return {"url": url, "status":False, "error": str(e)}

def download_parallel(url_list, opt, max_workers = 10) :
    log_data = []
    
    with concurrent.futures.ThreadPoolExecutor(
        max_workers = max_workers
    ) as executor :
        future_to_url = {
            executor.submit(
                download_video, url, opt
            ) : url for url in url_list
        }
        for future in tqdm(
            concurrent.futures.as_completed(future_to_url),
            total = len(url_list)
        ) :
            url = future_to_url[future]
            result = future.result()
            log_data.append(result)

    return log_data

# %% [markdown]
# ## download auidos parellely and save result metadata

# %%
_ = '''
# do this work using python file. ipython notebook is not suitable for this task.
results = download_parallel(
    vggsound_data[vggsound_data["train/test split"] == "test"]["url"] , ydl_opts, max_workers = 50
)

with open(VGGSOUND_METADATA_PATH, "w") as fp :
    json.dump(
        results, fp
    )
'''

# %% [markdown]
# # re-download missing audio

# %% [markdown]
# ## filter information of videos that were failed to downloaded not due to youtube related problem

# %%
with open(VGGSOUND_METADATA_PATH, "r") as fp :
    data=json.load(fp)

redownload_video_list = list(filter(
    lambda record : record["status"] == False and "errno 2" in record["error"],
    data
))


print("videos to re-download :")
print(redownload_video_list)
print("total", len(redownload_video_list), "to download")

print("downloading..")
results = download_parallel(
    list(map(
        lambda record : record["url"],
        redownload_video_list
    )),
    ydl_opts,
    max_workers = 50
)
print("\n")
print("download completed")

for r1 in results :
     for r2 in data :
          if r1["url"] == r2["url"] :
               data.remove(r2)
               data.append(r1)
               

redownload_video_list = list(filter(
    lambda record : not record["status"] and "errno 2" in record["error"].lower(),
    data
))

print("videos to re-download :", len(redownload_video_list))
print(redownload_video_list)

with open(VGGSOUND_METADATA_PATH, "w") as fp :
    json.dump(
        data, fp
    )
# Out:
# videos to re-download :
# []
# total 0 to download
# downloading..
# 0it [00:00, ?it/s]
# download completed
# videos to re-download : 511
# [{'url': 'https://www.youtube.com/watch?v=-7sg--aJdrc', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/-7sg--aJdrc.webm.part' -> './vggsound_tmp/-7sg--aJdrc.webm'"}, {'url': 'https://www.youtube.com/watch?v=-GOaBCyC5Js', 'status': False, 'error': "[Errno 2] No such file or directory: './vggsound_tmp/-GOaBCyC5Js.webm' -> './vggsound_tmp/-GOaBCyC5Js.webm'"}, {'url': 'https://www.youtube.com/watch?v=-7tYmeOmsRg', 'status': False, 'error': "[Errno 2] No such file or directory: './vggsound_tmp/-7tYmeOmsRg.webm' -> './vggsound_tmp/-7tYmeOmsRg.webm'"}, {'url': 'https://www.youtube.com/watch?v=-KqXcm-I2zY', 'status': False, 'error': "[Errno 2] No such file or directory: './vggsound_tmp/-KqXcm-I2zY.webm' -> './vggsound_tmp/-KqXcm-I2zY.webm'"}, {'url': 'https://www.youtube.com/watch?v=-K-ccLMFE5M', 'status': False, 'error': "[Errno 2] No such file or directory: './vggsound_tmp/-K-ccLMFE5M.webm' -> './vggsound_tmp/-K-ccLMFE5M.webm'"}, {'url': 'https://www.youtube.com/watch?v=-LxtesAXWIU', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/-LxtesAXWIU.webm.part' -> './vggsound_tmp/-LxtesAXWIU.webm'"}, {'url': 'https://www.youtube.com/watch?v=-aK9JKAGme0', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/-aK9JKAGme0.webm.part' -> './vggsound_tmp/-aK9JKAGme0.webm'"}, {'url': 'https://www.youtube.com/watch?v=-Y-UegG9tLw', 'status': False, 'error': "[Errno 2] No such file or directory: './vggsound_tmp/-Y-UegG9tLw.webm' -> './vggsound_tmp/-Y-UegG9tLw.webm'"}, {'url': 'https://www.youtube.com/watch?v=-u-40BIU1HE', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/-u-40BIU1HE.webm.part' -> './vggsound_tmp/-u-40BIU1HE.webm'"}, {'url': 'https://www.youtube.com/watch?v=0-jDld11jhw', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/0-jDld11jhw.webm.part' -> './vggsound_tmp/0-jDld11jhw.webm'"}, {'url': 'https://www.youtube.com/watch?v=0KAeUAAoVnY', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/0KAeUAAoVnY.webm.part' -> './vggsound_tmp/0KAeUAAoVnY.webm'"}, {'url': 'https://www.youtube.com/watch?v=0T39A4knSu4', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/0T39A4knSu4.webm.part' -> './vggsound_tmp/0T39A4knSu4.webm'"}, {'url': 'https://www.youtube.com/watch?v=0VW4nelMODc', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/0VW4nelMODc.webm.part' -> './vggsound_tmp/0VW4nelMODc.webm'"}, {'url': 'https://www.youtube.com/watch?v=0eA2QcSRgh0', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/0eA2QcSRgh0.webm.part' -> './vggsound_tmp/0eA2QcSRgh0.webm'"}, {'url': 'https://www.youtube.com/watch?v=0dUL0EweBEY', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/0dUL0EweBEY.webm.part' -> './vggsound_tmp/0dUL0EweBEY.webm'"}, {'url': 'https://www.youtube.com/watch?v=0ju5RWqEwGQ', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/0ju5RWqEwGQ.webm.part' -> './vggsound_tmp/0ju5RWqEwGQ.webm'"}, {'url': 'https://www.youtube.com/watch?v=0nYltlo90Zc', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/0nYltlo90Zc.webm.part' -> './vggsound_tmp/0nYltlo90Zc.webm'"}, {'url': 'https://www.youtube.com/watch?v=1BivKH8w7Fo', 'status': False, 'error': "\x1bERROR:\x1b Unable to rename file: [Errno 2] No such file or directory: './vggsound_tmp/1BivKH8w7Fo.webm.part' -> './ ...

# %% [markdown]
# ## postprocess

# %%
mp3_name_list = sorted(glob(os.path.join(MP3_FILE_ROOT_PATH, "*")))

id_list = sorted(list(map(
    lambda x :  os.path.basename('.'.join(x.split('.')[:-1])),
    mp3_name_list
)))

id_list
# Out:
# ['---g-f_I2yQ',
#  '--U7joUcTCo',
#  '--i-y1v8Hy8',
#  '-0BIyqJj9ZU',
#  '-0jeONf82dE',
#  '-0p7hKXZ1ww',
#  '-0pJqpNjft4',
#  '-0vPFx-wRRI',
#  '-0yRK50zyTI',
#  '-1BtY81-D54',
#  '-1EXhfqLLwQ',
#  '-1pRmoJIGQc',
#  '-2-wdcN5vOw',
#  '-2Dm0VjW8oM',
#  '-2sE5CH8Wb8',
#  '-2sOH8XovEE',
#  '-2xiZDEuHd8',
#  '-3-4qmWSJXU',
#  '-3Kv4fdm7Uk',
#  '-3RH8_aeZkk',
#  '-3YWuPXHknk',
#  '-3b9gwBYXp8',
#  '-3rHVsIj1M8',
#  '-3z5mFRgbxc',
#  '-40nDU5Ecgg',
#  '-4DpBHTuc88',
#  '-4bPiXbovf0',
#  '-4kkGS4-qVM',
#  '-4pmCrSdMhg',
#  '-4viN_EoxOA',
#  '-5CGQGSFGyg',
#  '-615mGonUqU',
#  '-79qo5MUYBk',
#  '-7IhwezUrUA',
#  '-7TanrCbmME',
#  '-7YESdyyHVw',
#  '-7sg--aJdrc',
#  '-7tYmeOmsRg',
#  '-8C-gydUbR8',
#  '-8cgbhIR_pw',
#  '-8lzdlqUtJQ',
#  '-8pCMgGKZY8',
#  '-A1o1Egi20c',
#  '-A3zsFeU_OI',
#  '-ABOfhcXwt8',
#  '-AIzKe9X0hA',
#  '-AMsYmKRnWE',
#  '-ANxUxvGASw',
#  '-AeiYb4vDK0',
#  '-Am9MfJ6Z2o',
#  '-BmjFZ1xu5Q',
#  '-By6I234TSs',
#  '-ByoSbgzr4M',
#  '-CGkSDY0mWI',
#  '-COelgvUEW4',
#  '-CZ1LIc8aos',
#  '-Cr0WQoFQQs',
#  '-D64b_8YJK4',
#  '-DnZ_ZY3lgA',
#  '-DwwSHC2jLs',
#  '-E5o64ACjm0',
#  '-Ezk-jIm6kM',
#  '-FKrYTj_eCU',
#  '-FoTxwPOz3U',
#  '-G04QpzSpbU',
#  '-GLVzwHQwtw',
#  '-GOaBCyC5Js',
#  '-Gr9P8Abnlk',
#  '-HAoExLVs6Q',
#  '-HMEhGV38GM',
#  '-IKnJa9U66I',
#  '-ILKJyVxhBI',
#  '-IZbvEO9wzU',
#  '-Igq1W20Gi8',
#  '-Ii-kc3ufho',
#  '-JBH9j7-h8U',
#  '-JGpAlLrSD0',
#  '-JJmkQYZA-4',
#  '-JTbHL7OKf0',
#  '-JUBdOr8Hes',
#  '-JUhUI_KvUI',
#  '-K-ccLMFE5M',
#  '-K1BRF6qng8',
#  '-KA76yUSK44',
#  '-KBH8YmHR-0',
#  '-KCYC-n5Uag',
#  '-KTabIWnPSg',
#  '-KqXcm-I2zY',
#  '-Lmibx_Iu_E',
#  '-Lv13WPa4xk',
#  '-LxtesAXWIU',
#  '-M6K3QoHh40',
#  '-M7ZNV6gLo0',
#  '-MIwX2AaUas',
#  '-N00SskHxS4',
#  '-NCa3eFLULw',
#  '-NQl3o-CGwY',
#  '-NRx0SBMjo0',
#  '-NwBdmVSg1w',
#  '-O4W3NA5-uA',
#  '-OAyRsvFGgc',
#  '-OEJFMpQ-ko',
#  '-OJzsMV1G1A',
#  '-OVb-UG8yJw',
#  '-OxoxrlzLXA',
#  '-P2cxvGQUvk',
#  '-PvlrLjIAYo',
#  '-PyXfNxnHKs',
#  '-Q3MX7Tgx_E',
#  '-Q_UXiwWR_c',
#  '-Qowmc0P9ic',
#  '-QsPqh8Kyrc',
#  '-RBs9pPhHY8',
#  '-RO4IF8Qv3c',
#  '-RUIfdLiXdk',
#  '-S-TDT5oq0Q',
#  '-SWaCArvQug',
#  '-Sd-j0rKeKw',
#  '-T2MO0xBNwM',
#  '-T8L4SVm3u0',
#  '-Tok_g_jgE0',
#  '-UKH_6moRZc',
#  '-VLOm8cJZRI',
#  '-VevyIayGM0',
#  '-Vo4CAMX26U',
#  '-VpYtEHyLm4',
#  '-WVmsxGujF0',
#  '-Wd5YV97ftU',
#  '-Wsuo4VDwfE',
#  '-XwtCzUaN1I',
#  '-XxUW9gW6mc',
#  '-Y-UegG9tLw',
#  '-Y8sJDoL1YA',
#  '-YfaQljuwwA',
#  '-YwPSwhe2jo',
#  '-Z1ZSWDouUU',
#  '-ZFNLu4HclQ',
#  '-ZJqu_4zLMc',
#  '-ZSgg6jFUd8',
#  '-Zl_ZkDmZHE',
#  '-_QPd-VskKY',
#  '-_f_ClsDxyc',
#  '-_umX4zgLVY',
#  '-_yRmyG71Z0',
#  '-aK9JKAGme0',
#  '-aOxR6ILsw8',
#  '-aUJLRXkj-Y',
#  '-aXWYfAdovc',
#  '-b42018ceoE',
#  '-bJPDtT31p0',
#  '-c6baaENcjA',
#  '-cA9HsnV1ao',
#  '-crF-0Z7l3o',
#  '-ct58kOlLfs',
#  '-d1KR2BSfHM',
#  '-dRucPKqTFc',
#  '-e4wXAy1iVo',
#  '-f1DNyngKVY',
#  '-fAGzY9rnaA',
#  '-fAVezaAX18',
#  '-fJsZm3YRc0',
#  '-fPdOa99Iwg',
#  '-fTfRh0_RQ4',
#  '-fz6omiAhZ8',
#  '-g-GjgEq8l4',
#  '-gAzofSmRiY',
#  '-gCqnkIUmp0',
#  '-gSfPQqi6nI',
#  '-gVYT75KBOU',
#  '-galdW8VGEQ',
#  '-gz_moHFwl4',
#  '-h5ZGw9Ci5c',
#  '-hA3ZkfDz30',
#  '-hJ1YTZ5AGI',
#  '-hSwZyPPJTc',
#  '-hYRFCQdbLg',
#  '-hb5BJ9xxBQ',
#  '-hedbpc8T0E',
#  '-hfAbHHlj44',
#  '-hn5Sfg7kX0',
#  '-hss7xpzIVc',
#  '-iF4a6f5PJ8',
#  '-inB65exXFU',
#  '-jA7nRwQp_E',
#  '-jFSYIHh6zc',
#  '-jVXNEvUJss',
#  '-jZENGDFArw',
#  '-jaY3LS3Dv0',
#  '-k-hxP5eWko',
#  '-kPDH9n0PG4',
#  '-kWlE2dkoxc',
#  '-kZVoaYYU6o',
#  '-l-E3kyNcag',
#  '-lJctvybAJ8',
#  '-lPXTBXa0tE',
#  '-mKtgDnG0oM',
#  '-mN5Uo1_TRI',
#  '-miI_C3At4Y',
#  '-nDPmlHReow',
#  '-nJbGyPg6BY',
#  '-nQ9a0P1TlY',
#  '-na-0NBG5Ow',
#  '-njdG2dcQx0',
#  '-nlkWWphiaM',
#  '-oGJwGEsIiA',
#  '-oOARU0JwWE',
#  '-oSzD8P2BtU',
#  '-ocADGlyaHc',
#  '-p-pVVp0Ibo',
#  '-pBFsYisTCM',
#  '-qtYcqvW_oc',
#  '-qxw8nbLj_0',
#  '-r-k-BvQbRM',
#  '-r2-9oyIzkQ',
#  '-r3nM90RCNs',
#  '-r4vbRkcndc',
#  '-rTTPoBJNI4',
#  '-rb6uia1wSo',
#  '-rcoSOKo-qM',
#  '-rqhMzJRYoc',
#  '-s5ZidRvnjQ',
#  '-spqqACI6UQ',
#  '-t-htrAtNvM',
#  '-tm7JvKYFcE',
#  '-u-40BIU1HE',
#  '-uD3ZbhFTnk',
#  '-uGHAvfqs2I',
#  '-uaTK8sa5Ms',
#  '-ugSeFtSqhU',
#  '-vAtBe4LMCQ',
#  '-vBj0PZ1RF0',
#  '-vNGqcDA6oE',
#  '-vZ-_4oFCzs',
#  '-vg8ttgP32I',
#  '-w8maIWtnUk',
#  '-wP6ycrwb9U',
#  '-wQ8El8J_dE',
#  '-wi8kPVJLcw',
#  '-wnDAPcoPsk',
#  '-xQbyezhw_k',
#  '-xTVeti9VkQ',
#  '-xfgovG6-KU',
#  '-yI3BN2OrO4',
#  '-yrglmBmErg',
#  '-z3AAq0FK-0',
#  '-z3n74RK92U',
#  '-z4OZ7ls5Bo',
#  '-zCtwbk005g',
#  '-zI7FN8cMIE',
#  '-zIrltLewfc',
#  '-zNEcuo28oE',
#  '-zSyfcXmHdk',
#  '-zfmvtpsQq8',
#  '-ziWHyk_fYQ',
#  '-zoQRlTGmt4',
#  '-zwjoyBo2s8',
#  '0-6N0Qagy5A',
#  '0-EgET9q3qE',
#  '0-jDld11jhw',
#  '0-o0oZvSFOk',
#  '007P6bFgRCU',
#  '00KM53yZi2A',
#  '00QQLLcny14',
#  '00cREXaIlnQ',
#  '00gxEsWO4mo',
#  '00wORCOKNHw',
#  '00z0M1DJyAw',
#  '01Iho7loxL0',
#  '01SaXyGY5SM',
#  '01j_x89dowI',
#  '01kxsUBtBZY',
#  '02Ak1eIyj3M',
#  '02UvvE1oA1I',
#  '030h_KwNm-g',
#  '03Q2SbeP_cw',
#  '03zeVlBWhdY',
#  '0439dMJj-FY',
#  '0474eRAlFLY',
#  '04L5PnWm3SQ',
#  '04QV0Xi5YTk',
#  '04zBqiZ6M4w',
#  '052VMqTM4Xs',
#  '054iiUoKoyo',
#  '05GsUEyThd8',
#  '05uiW8xh5QU',
#  '064Ilsz8Fzg',
#  '067izxXJJu4',
#  '06pzMwo6VHA',
#  '076qdKSC8nU',
#  '07FxCXxknY4',
#  '07I7v5ISD7Y',
#  '07bi-w2VKeg',
#  '08Cm_RuvHmk',
#  '08mf5GxT820',
#  '09kqMqn5rWs',
#  '09pZj6CEvRw',
#  '0B7fwvTtvLM',
#  '0BCkxfdk6fk',
#  '0BauNGmZtTU',
#  '0Br877mW7_c',
#  '0CA5CPHRXDc',
#  '0CEsVHHkwww',
#  '0CQnnJq9xn0',
#  '0CTgEP0SIVg',
#  '0Cl6hXpryhY',
#  '0Cu33yBwAPg',
#  '0CzC0-cXe8M',
#  '0D8KognM4uY',
#  '0DOFzYwOoPg',
#  '0DzsPL-xElE',
#  '0E6KS8B6DMc',
#  '0EOQco76eXQ',
#  '0EyJ15KLxg4',
#  '0F04c_rY4aw',
#  '0FEd3Pd-ksw',
#  '0FHSJnza9P8',
#  '0FjrveIENzI',
#  '0G50t4FlbIA',
#  '0GBi8uR4ZeM',
#  '0H25ve3qts4',
#  '0H2tR-oOvIY',
#  '0H814XXq-WQ',
#  '0HBJuYt2Eys',
#  '0HXYdGGKV2k',
#  '0HbhE91JB-k',
#  '0IqPUUWnnd8',
#  '0Iy18mslB4A',
#  '0IyXjTa_wmQ',
#  '0IzhjqyDzt8',
#  '0J5LtHU3F9Q',
#  '0J_TdiZ3TKA',
#  '0JkiTl-4B5E',
#  '0Jq6WJLLSIk',
#  '0KAeUAAoVnY',
#  '0KIC9xmmD8g',
#  '0KOPvSUlNjI',
#  '0LY5zuRlIac',
#  '0LwSy-xZSPw',
#  '0MU2SG5ME1E',
#  '0MdeE8BM9RI',
#  '0N0C0Wbe6AI',
#  '0N3-lCzOQPI',
#  '0N6S5OoG7Vg',
#  '0N9EN0BEjP0',
#  '0NIE-eDk92M',
#  '0NLXz4JgvcQ',
#  '0NQXsEwBqAk',
#  '0NZLG7HMiLg',
#  '0NZQRllfNhE',
#  '0O-gZoirpRA',
#  '0O463Ft4mVY',
#  '0O5xrYEZlSM',
#  '0OFlTh2_Obo',
#  '0OH28bnOdEE',
#  '0OLYyjqNdn4',
#  '0OY8XXZ98rw',
#  '0Olm321vgk8',
#  '0OyVe-lZS64',
#  '0PHUQku2P5I',
#  '0PKdFG3iB8w',
#  '0Q1uQL5SL7U',
#  '0QPuoCmYU60',
#  '0QSPtpp1HN8',
#  '0QYedLfOwcI',
#  '0QabiRBcEKc',
#  '0R85JknaH-w',
#  '0RHZd1P_H2s',
#  '0RMYLychMXc',
#  '0RZRFj7zDnQ',
#  '0Rjyih3W0Is',
#  '0Rqa18lmDtw',
#  '0SLv6CmZas8',
#  '0SnjS2w_c80',
#  '0T39A4knSu4',
#  '0T966F09Q_8',
#  '0TV9zvfwFhs',
#  '0TuhcsOwEEs',
#  '0U7mQ5GYMX8',
#  '0U9_6RyH3_M',
#  '0UEWX-2epho',
#  '0UF1FHDPM1A',
#  '0UJpeR9-ayg',
#  '0UeEkqkZmvo',
#  '0VOkoqNMHAc',
#  '0VW4nelMODc',
#  '0VXKu_hIxpk',
#  '0W1sNicXboU',
#  '0WTf_N9NPDw',
#  '0W_wPc-zV3I',
#  '0Wkk9iNzA9c',
#  '0Wxl_LzqguI',
#  '0XBOuAycZ-k',
#  '0XDEooC1h7s',
#  '0XFFOBzJ3aw',
#  '0XSNrKgA94g',
#  '0XxinBtKouQ',
#  '0YIWrXgCjiM',
#  '0YI_WYJVv2M',
#  '0YTieIiZNN4',
#  '0YiyCktu7bs',
#  '0Zm0ti8edsQ',
#  '0ZxpQ87jdgQ',
#  '0_8-g2rof7E',
#  '0_B2YnBAz3A',
#  '0_FFqLukmHk',
#  '0_O6nVfnCH8',
#  '0a264PE9qEY',
#  '0a4UPHowiOM',
#  '0aJZPu-3anY',
#  '0aaLWD7TUSU',
#  '0bBJkY4_zs8',
#  '0bJgHzGSqK0',
#  '0bKpv6YBl7g',
#  '0bobzCB2ObQ',
#  '0c78GAZ0jLY',
#  '0cNYPgD6cEA',
#  '0d6YdyxkXzQ',
#  '0dC1f6bdyr4',
#  '0dC6Ay0oqWk',
#  '0dUL0EweBEY',
#  '0eA2QcSRgh0',
#  '0eDN0YmnJRY',
#  '0eTrzI5-ong',
#  '0eZHWqzsRqU',
#  '0f0Rq7e5yX8',
#  '0f2Q2J0AwQQ',
#  '0fDDlf0Mrp8',
#  '0foC-4n-eH0',
#  '0fsFWLev-q4',
#  '0g-KosNgMYA',
#  '0g4SlqjORM4',
#  '0g_-KI5NZ-E',
#  '0glBUluF4Yk',
#  '0hOD_iIeePk',
#  '0hWIKYNSEPE',
#  '0hdkmTWLnw8',
#  '0he6VV5Y9Bg',
#  '0hfU27A6tus',
#  '0hjqlmdPT6g',
#  '0iX0QmnbrK4',
#  '0iiwZ2_9Vi8',
#  '0izHOfrwPn4',
#  '0jiu0RNizU8',
#  '0ju5RWqEwGQ',
#  '0jy-sVREk4o',
#  '0kK-PnupAow',
#  '0kQkVbOikzQ',
#  '0kqQNBR09Rc',
#  '0lPcHRhXlWk',
#  '0loP4WNnL2k',
#  '0m9-5BkL4Mc',
#  '0mNvPaqfwUI',
#  '0mZQ6Q-viPw',
#  '0mkj5A9qg9A',
#  '0n-Z2AQCRnU',
#  '0n56ajMNoMA',
#  '0nYltlo90Zc',
#  '0nib7bMm8BA',
#  '0nvBTp-q7tU',
#  '0olhNr566Z0',
#  '0onKcFY1Tu0',
#  '0pHTgC1Frnw',
#  '0q1zNZNjzaA',
#  '0q6GOUn_dhU',
#  '0q9FUj_2qMc',
#  '0qDs_aC0LwI',
#  '0rDaP06do8c',
#  '0rKz4unZteU',
#  '0s62qg0kfJE',
#  '0sT6vnChbrc',
#  '0slFEpnTKkY',
#  '0slyl34xWug',
#  '0ssOpzqkojU',
#  '0t1jQa_Lj_E',
#  '0teMcpgy9Jo',
#  '0ti14lvd2Aw',
#  '0u5dddSWuj8',
#  '0uMEyyhzaqU',
#  '0ua6AnyVwbk',
#  '0unbxXUE_c0',
#  '0ut4if4B6zM',
#  '0vFPs6XsU_Q',
#  '0vXqf9ix8LE',
#  '0vg9qxNKXOw',
#  '0w7pCxwXzVc',
#  '0w9PLY1owzk',
#  '0welW-8hB1c',
#  '0wzsE67O5tE',
#  '0x9TnOQ5Nhw',
#  '0yxJzCQW5zI',
#  '1-J5ByJcrc4',
#  '10Y5oGN2J30',
#  '10YXuv9Go0E',
#  '10aBef0Ghkc',
#  '10aF24rMeu0',
#  '10hGfv89L3g',
#  '10rH37YYvKU',
#  '115l3adqQ1M',
#  '11KWMKfalJo',
#  '11ruZHgyTKM',
#  '126AbihZt28',
#  '12C-RCb6UFw',
#  '12Sd9Aap5ww',
#  '12T-9dLEbY8',
#  '12eRdXA6Iig',
#  '13Ij0Y-m7N0',
#  '13W_9xdaOZE',
#  '13k0xa_vTFI',
#  '14XML4NbS38',
#  '14jcqHjMXcI',
#  '14lBeX_dOHU',
#  '14tRPoQA4q0',
#  '15703UC_0b0',
#  '15Mw2jyyHk0',
#  '15aMq3FEyjQ',
#  '15pi8h_bHQE',
#  '169a2JSphHA',
#  '16CvcIXIjzQ',
#  '16TsDMjHzYU',
#  '17CpJxlwzNg',
#  '17K-oEuH1p0',
#  '17L2VkXtcQ0',
#  '17Ne52PWgsI',
#  '17QNWSDwhm0',
#  '17WW_p1N7BQ',
#  '17cwMjZ3MZs',
#  '17yDXvJTdeo',
#  '18212B4yfLg',
#  '18HRNQyo9mg',
#  '18PLoJDIvIQ',
#  '18aaA2efGng',
#  '18r-Vtspi8g',
#  '190Zx0wVrhQ',
#  '19_c58yNYVw',
#  '19knOj43yZE',
#  '19r6_MQei4M',
#  '1ACn3u5UnBw',
#  '1B-RuZgSqf8',
#  '1B0VJf7jRDg',
#  '1BYZiONhW3c',
#  '1BivKH8w7Fo',
#  '1Bv79-2FK-g',
#  '1CGx8zxQFx4',
#  '1CIh0UNxXrI',
#  '1CRvPsMwqrc',
#  '1CZ-bybGzu4',
#  '1D4LxbOVn1I',
#  '1D6UsaTflJ8',
#  '1DDBWHBebR4',
#  '1DG7FLVxKDA',
#  '1DJYkemV_0I',
#  '1DRZS9_-8C0',
#  '1De-OI8YG-M',
#  '1DlGh4su-Ms',
#  '1DrrBnFlylU',
#  '1EH6atYydBc',
#  '1ENC2smc8Ig',
#  '1EWkwWXwI1g',
#  '1ErGsKIlhAI',
#  '1EuGaYmvlXM',
#  '1F-jIu9oy6A',
#  '1F23RciUwDE',
#  '1F3_bvIT0ig',
#  '1F9zCsJyw6k',
#  '1FU5odlgLmo',
#  '1FWUnWVX5Xk',
#  '1FnA3w94zXI',
#  '1G6wtnmdZhE',
#  '1GDAnA4hAqQ',
#  '1GI75yXlrTk',
#  '1GyO48dbGCI',
#  '1HUCwslugK8',
#  '1HswRpBt6mI',
#  '1I5QQBbZP8g',
#  '1Isq_KJHriU',
#  '1JSbmO1NQzk',
#  '1JY4rwQZn3s',
#  '1J_j6c2uQaM',
#  '1JfwuwHV0hc',
#  '1Jo_WQrPc1Q',
#  '1JsIcP2nXMw',
#  '1K1hxgzudsM',
#  '1KLmIS-v60U',
#  '1Kb6GNZClSM',
#  '1KiFXylkPpg',
#  '1KpqiBhyP7Q',
#  '1KpvQAM14Ic',
#  '1LA8BxMlXSY',
#  '1LPIxPA6-O8',
#  '1LTxZ2aNytc',
#  '1MTKUN3uFrs',
#  '1MaEJRh2oGY',
#  '1MgcrYdYas0',
#  '1MlgXBFnJl8',
#  '1NV87x_JYnQ',
#  '1NkUBIl2Plw',
#  '1Nm7UqNx9zs',
#  '1Ny5ZlcBlcQ',
#  '1O-WeYTRS4w',
#  '1OFDyTzUj24',
#  '1OFOElP7bqc',
#  '1ON1iLkUPp8',
#  '1OpNI5DjxC0',
#  '1P9yEzO1Bic',
#  '1PAb2MoavDc',
#  '1PN-bfs2EhY',
#  '1PPboJuO1Ks',
#  '1QBsc_IXg8U',
#  '1QtsF8qkX1Y',
#  '1RAcDEFEszA',
#  '1RfdLnNRLfA',
#  '1RhYdQnZ_hw',
#  '1RwhRTe-OKk',
#  '1S4SJnWsq1s',
#  '1SBP-Dy8_II',
#  '1SJFTbu1abo',
#  '1SPu2hsIhDw',
#  '1TAOyk0Xgss',
#  '1TJrceFMGrU',
#  '1TP8JyI5vHI',
#  '1Tg9VvRZN5k',
#  '1Thl21awe2g',
#  '1U38Q2MpYM4',
#  '1Uj_ulATth0',
#  '1V-_jMSJR6A',
#  '1VHm2PacRWc',
#  '1Vt6qYw1BnQ',
#  '1W-KLZJwXkc',
#  '1W2FOzSXsxs',
#  '1W83RMliwv8',
#  '1W9fwoe4O-M',
#  '1WI9921OeRc',
#  '1WLMVX_Y2Pk',
#  '1XO0SqsZhHU',
#  '1XZyIaJT8Lw',
#  '1Xmw9VUzvLY',
#  '1XxHC7eMNg8',
#  '1YFa9CpH7Kc',
#  '1YWeSXAXwQE',
#  '1ZXe1qg_xeg',
#  '1ZgXgyEJSbc',
#  '1ZloXG3iHl8',
#  '1ZwVoNUvaAE',
#  '1_0T2ZIjWnw',
#  '1_JeO9Pg1aQ',
#  '1_Q80fDGLRM',
#  '1_v-Kro86Io',
#  '1_xoCNmTn3Y',
#  '1_yyvTRVoZQ',
#  '1a-ODBWMUAE',
#  '1aDnyPubxdY',
#  '1aexyJH0jU8',
#  '1bIH_Qh_clk',
#  '1bSLrOlRIB4',
#  '1bbyaXEVouE',
#  '1cqcTbDxsHM',
#  '1cwGW0cBdRs',
#  '1cwReJkXLVo',
#  '1cxvg7qu0G0',
#  '1dyFP4MGkIM',
#  '1e0_4dwF9A4',
#  '1eBzpkIY-TY',
#  '1eP5LSjyge0',
#  '1f-L1M-S6RQ',
#  '1f-s2gYqyh8',
#  '1fDGejVDAHU',
#  '1g3n6Zaqid8',
#  '1g6sdWOc9k4',
#  '1gSwLBNvEWE',
#  '1gWu-9hPzFs',
#  '1garMoYilAY',
#  '1hIg-Lsvc7Q',
#  '1hJnxzlxnQs',
#  '1hKSlZZ5T50',
#  '1hWAOReJehw',
#  '1hba9jmspEQ',
#  '1hknEtsmdOc',
#  '1hoUEfsTmdE',
#  '1hsOUPwn21E',
#  '1hwkxJOl1PY',
#  '1iP-Y7FDMys',
#  '1ib1pd6mHoE',
#  '1j13NdQiw8c',
#  '1jHVyPknyhM',
#  '1jq7zSF_v7s',
#  '1k0R3npPdKI',
#  '1kV-NUwWfSc',
#  '1kiR-BU9Fik',
#  '1lLobOtsIFA',
#  '1lMCacmGZ8I',
#  '1mGE3y19p9g',
#  '1mMqLP36sCQ',
#  '1ma4b_TsEVA',
#  '1mfghenMj_E',
#  '1mkIuq3rjUg',
#  '1mzzeozuZ6o',
#  '1n5uFGk2pnc',
#  '1n6JyJt4kJ4',
#  '1nNXaI04SEg',
#  '1nUqhH8bAPk',
#  '1n_s2Gb5R1Q',
#  '1nbCJJtsruI',
#  '1oJAVJPX0YY',
#  '1o_gJNHZBZs',
#  '1obzCbmFpa8',
#  '1owKdIYYYeg',
#  '1p3NSKpuJDs',
#  '1p5jl5JeZx8',
#  '1pMMz2vm6JE',
#  '1pViEqMXJH0',
#  '1q8kkQhS97g',
#  '1qRi4bT_t3Q',
#  '1qh5aSSZrxA',
#  '1rJWW_KqeAw',
#  '1rZMNdoEZzw',
#  '1roSKWxidVo',
#  '1rpJo68d5Qw',
#  '1rtXsGC-q3Q',
#  '1tC7bTilFWk',
#  '1tiz4gWXVGI',
#  '1tjJmArxVBM',
#  '1tn0MJTOprg',
#  '1tobDIRRV0A',
#  '1tz4xNRRR4M',
#  '1u1orBeV4xI',
#  '1uCzQCdCC1U',
#  '1uLkSMHxvZY',
#  '1uhuVsFGe6E',
#  '1veIcvGPRYw',
#  '1vrJPFfLMvA',
#  '1vrR6Im_RDo',
#  '1vy-ZxTMQf4',
#  '1w_iLXQb-9Q',
#  '1wdCX1HmRyk',
#  '1woaZGPrY9g',
#  '1wqJ9KDfcME',
#  '1xRNQCP4MbE',
#  '1xS-iGBR2b8',
#  '1xYpHbg0fEE',
#  '1xhSBniwGbM',
#  '1y-PYHnpvZs',
#  '1yKGjTOk7NY',
#  '1yNBf7QG__4',
#  '1yWGmdevTuM',
#  '1yfwHkdCucc',
#  '1yxij2nsbZw',
#  '1z19uJK6SB0',
#  '1z96Z0DSNlM',
#  '1zIoNTdug0U',
#  '2-XyCIq8Yp0',
#  '20Nlj7Cz4E0',
#  '20Qksqlj4dc',
#  '20qZLse0acs',
#  '21Dc8a8X8qg',
#  '21I0YiLHzvg',
#  '21V-gDHQPsw',
#  '21lu8Iaf9II',
#  '22OjhEqCWj8',
#  '22gk62Sijnc',
#  '23FY9sjfgM8',
#  '23HYypV2gcM',
#  '23iz1nJSRkE',
#  '23xC7lTBikU',
#  '24E8nk18LB0',
#  '24FO7pGNJKU',
#  '24tWz7gmngI',
#  '253aGgk7NSE',
#  '25PvbXDbZO8',
#  '25QsgUI0x8U',
#  '25ZuFwyx_bs',
#  '26OpBUZbdPw',
#  '26dqZUTv5os',
#  '26oZCMP4Kqo',
#  '27rw1ni1k0c',
#  '28Ih0rDx-Y4',
#  '28StN9ykZ68',
#  '28_H0GAijwc',
#  '28ehZa0fzmo',
#  '28p0DrP3KgI',
#  '28wBrNjHXOM',
#  '29MZ0dwOBOM',
#  '29WrIcP3l44',
#  '29ZWMYIEq3g',
#  '29dG2jHRuXI',
#  '29dwfsI1XlQ',
#  '2A63oYgod8Y',
#  '2ASyuuVhr6M',
#  '2ATRc7EonvI',
#  '2B-xGbzOjYY',
#  '2BMOGrFU_m8',
#  '2BNSDDwGxM8',
#  '2Bljhdt61Y4',
#  '2BuuLRDcgmY',
#  '2C4aXzGI2eI',
#  '2C7SzKv2uLU',
#  '2CEb1hYM3EA',
#  '2CIWnYMxFCw',
#  '2CidaVnd60g',
#  '2D0okq6-SBo',
#  '2D2AJ6Dg0-U',
#  '2D7jgszuoKA',
#  '2Dr7gDL46NU',
#  '2DyD824KPFM',
#  '2E31rvMg-rE',
#  '2EYGJpU7juM',
#  '2EaYSObne7M',
#  '2FJWwHQcXBk',
#  '2Fbt9QiLWWc',
#  '2Fdau5KTEls',
#  '2FrXzcm4YMc',
#  '2FtVHJ91gDc',
#  '2FxRgLF37kw',
#  '2G4lyzAZ1vk',
#  '2GGNgvdRcAs',
#  '2GOPuGmcHH0',
#  '2GuH1UJxQOk',
#  '2H3miNoF_Z8',
#  '2HZcxlRs-hg',
#  '2Hj6ogt1TJo',
#  '2Hjy0TDdpNI',
#  '2I0ns0crmrA',
#  '2IEoe3YvCJo',
#  '2INpPpv4NRg',
#  '2ISY5z0QQfc',
#  '2Ic1zm9mBjk',
#  '2Jpg_KvJWL0',
#  '2JpvRGz5Dq0',
#  '2K0NKi1wigk',
#  '2K5Px-N6BEI',
#  '2KEg1a42Wx0',
#  '2KNJPTMMD4s',
#  '2K_kjDyISPg',
#  '2L3tuvv5RRw',
#  '2LMxs_P1EhY',
#  '2LRhkMH48_Q',
#  '2LtEPWwp36E',
#  '2M0i--pR-To',
#  '2M9isBM1ChU',
#  '2MKPKDQcgVc',
#  '2MPvlAR1AJM',
#  '2Mkwgf0Pej0',
#  '2N2msWTHybg',
#  '2NESqWU89V0',
#  '2OOZIIosPX4',
#  '2Oe5kao1ycY',
#  '2P1uwGQfaPA',
#  '2PHV2xNjGVU',
#  '2Pl5B1Tpn1U',
#  '2PokKRlQ3tI',
#  '2QLjGVV5eDA',
#  '2REf8hLLYMw',
#  '2RHarmH7DEk',
#  '2S-YRM0p6cc',
#  '2SchRwpsT7s',
#  '2SesFX53_-Q',
#  '2SgGaIe_5vw',
#  '2Ssh4YWMroo',
#  '2Szah76TMgo',
#  '2T1P9ovsl4A',
#  '2T8OhRXZDTs',
#  '2TW5ZDk8_A0',
#  '2TjVbDWZvcE',
#  '2TprtMP1RDo',
#  '2Tx5L5RBXxw',
#  '2U-4QHS0QBc',
#  '2U5f3uTl7qg',
#  '2UXH7NW9ae8',
#  '2UvzCdos0nc',
#  '2VFVe0RCn7g',
#  '2VUAY7c9BSs',
#  '2VUXFpZh6xI',
#  '2Vg5WTQZqwI',
#  '2VjbDttFK44',
#  '2VptepDtAZ4',
#  '2VqKqjqvugc',
#  '2Vu6HtlYio4',
#  '2VuKP6zZDDc',
#  '2W27eT4HqtE',
#  '2W4dw8XuetE',
#  '2WTk_j_fivY',
#  '2WfJBpN4elI',
#  '2Wk4Y3_dMuc',
#  '2Wr7o5BG6e0',
#  '2XFrBXTnNY8',
#  '2XK3vXa-wgw',
#  '2XOTejBfF2g',
#  '2XQzahrQ_tE',
#  '2XR54m3kvn8',
#  '2YJpjSldLtg',
#  '2YW7WBtqzzQ',
#  '2YXcqoFlYFY',
#  '2Yo0MGR2kmA',
#  '2ZNKLUHeJtg',
#  '2ZUuFcJxl3c',
#  '2ZhiOvhUTGA',
#  '2ZogsGp-T4o',
#  '2_C5yMbxKpY',
#  '2_RltCGlGOA',
#  '2_SKjq21NTI',
#  '2__T6Q8rCCA',
#  '2_cTS4ctWtE',
#  '2_dEkCMxgfw',
#  '2aOS7PDaGWM',
#  '2b0eM8lWGCQ',
#  '2bCuw7U_Rac',
#  '2bEQQ35Wkdc',
#  '2bYyywE97aA',
#  '2cEM6Hu90v0',
#  '2dCFOYuetW0',
#  '2drXOn18U3Q',
#  '2e1tRszQIPE',
#  '2eDP3jKoUd4',
#  '2eWobSpugTw',
#  '2ehbByOUJjM',
#  '2es7oZzwLWM',
#  '2f7NnTVQzR0',
#  '2ffgd7k0vI8',
#  '2fi0m8ei_B4',
#  '2g5hx_rynAI',
#  '2gvw16YDwMA',
#  '2hCMb1rgLK4',
#  '2hNEs5VCQR8',
#  '2i1Gs32odx4',
#  '2i4UNf8tjvU',
#  '2iAO9PKZDGk',
#  '2j4dsRMuj4Y',
#  '2j9izxhyFlI',
#  '2jKheXvnT6o',
#  '2jn2amm53u8',
#  '2jpLS2TQjlI',
#  '2k6_k7K_ixg',
#  '2kDORB3vR8s',
#  '2kHcvpsu_QY',
#  '2kQCMxf0onU',
#  '2kdJKmgMcxU',
#  '2ke9wf3Ajkg',
#  '2laUv3y7OfA',
#  '2m2bdfsT_sk',
#  '2mYEjl-AOMs',
#  '2mkJkrFeqjc',
#  '2mw1UMcc_Ys',
#  '2nF5FG9GK9k',
#  '2nVGw0vvwG4',
#  '2nvQdsMdQ6o',
#  '2o4-lEtFb2k',
#  '2ofK2gAQue4',
#  '2ozaPdNvgp8',
#  '2p37j052q3o',
#  '2pHfgh_G1yo',
#  '2pV6t7CO0Bc',
#  '2pikqXJeOAg',
#  '2pt7WZBYeeI',
#  '2qAlWm3NES8',
#  '2qGjgfpQtFI',
#  '2qHRJAQDCDo',
#  '2qO-OQtOBK0',
#  '2qSknsEkmZI',
#  '2qg5P9IJ_9U',
#  '2qh8jLGVaYk',
#  '2qtDXB4wT8c',
#  '2r0iftxu5vc',
#  '2rK6HBRC8HQ',
#  '2rW2I6KmWhw',
#  '2rciuzaEEWo',
#  '2rdkLx56T1c',
#  '2ro_sQ7_vUM',
#  '2s1nykhFpIE',
#  '2sGnD9sd1xM',
#  '2sKmbnOi5S0',
#  '2sXQeWPD5z4',
#  '2sxYW0fvods',
#  '2szvfFHZTV0',
#  '2t8rYnARZuI',
#  '2tXE7snh6Ak',
#  '2uRe-e8RVEM',
#  '2uYTNgvxVwk',
#  '2uZt59va3Ss',
#  '2uagA3ujRtM',
#  '2v1rSA4FqlM',
#  '2vFqNsOPq3I',
#  '2vSF2Yh6o_k',
#  '2vYkvwD-fkc',
#  '2v_KyNpsyKs',
#  '2vcA_vgImHQ',
#  '2vycuIKwnnA',
#  '2vzUFWykARU',
#  '2wGvpfAkly0',
#  '2wIrHCaxBNU',
#  '2wsp3s4hIKs',
#  '2x373CrHD6E',
#  '2xBIHi3oqy4',
#  '2xCwG0Wju4s',
#  '2xQuWif8axE',
#  '2y7aiiaJPf8',
#  '2yX9079mMB4',
#  '2yllw7g5EkU',
#  '2ynzj7tMUVI',
#  '2yumaMbGybU',
#  '2z5yJ2qa_5I',
#  '2zO-nlygkFo',
#  ...]

# %%
vggsound_data = pd.read_csv("vggsound.csv", names=["YouTube ID", "start seconds", "label", "train/test split"])
vggsound_data["idx"] = list(map(
    str,
    range(len(vggsound_data))
))
#vggsound_data["result_file_path"] = \
#    f"{vggsound_data['label']}_{vggsound_data['idx']}.wav"

vggsound_data["result_file_name"] = vggsound_data["label"]+ '_' + vggsound_data["idx"] + ".wav"
vggsound_data

downloaded_data = vggsound_data[vggsound_data["YouTube ID"].isin(id_list)]

downloaded_data
# Out:
#          YouTube ID  start seconds                    label train/test split  \
# 0       ---g-f_I2yQ              1          people marching             test
# 36      --U7joUcTCo              0          people coughing             test
# 52      --i-y1v8Hy8              0           female singing             test
# 78      -0BIyqJj9ZU             30    people belly laughing             test
# 117     -0jeONf82dE             21           horse neighing             test
# ...             ...            ...                      ...              ...
# 199413  zz0fdUGTHWo             45  chimpanzee pant-hooting             test
# 199425  zzFdhaiG_Hk             95          popping popcorn             test
# 199441  zzbTaK7CXJY             30               wind noise             test
# 199458  zzqrZOq928w             55            train horning             test
# 199464  zzvCPtdNxNo             68      civil defense siren             test
#
#            idx                    result_file_name
# 0            0               people marching_0.wav
# 36          36              people coughing_36.wav
# 52          52               female singing_52.wav
# 78          78        people belly laughing_78.wav
# 117        117              horse neighing_117.wav
# ...        ...                                 ...
# 199413  199413  chimpanzee pant-hooting_199413.wav
# 199425  199425          popping popcorn_199425.wav
# 199441  199441               wind noise_199441.wav
# 199458  199458            train horning_199458.wav
# 199464  199464      civil defense siren_199464.wav
#
# [13543 rows x 6 columns]

# %%
'''
for vid in id_list :
    row_data = downloaded_data[downloaded_data["YouTube ID"] == vid]    
    label = ',,'.join(row_data["label"].tolist())

    class_list = []
    for _, row in downloaded_data.iterrows() :
        labels = row["label"]
        idx = row["idx"]

        result_file_name = f"{labels}_{idx}.wav" 

        row_data["result_file_name"] = result_file_name
'''

downloaded_data["result_file_name"] = downloaded_data["label"] + '_' + downloaded_data["idx"] + '.wav'
downloaded_data
# Out:
# /tmp/ipykernel_1050190/1462908277.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downloaded_data["result_file_name"] = downloaded_data["label"] + '_' + downloaded_data["idx"] + '.wav'
#          YouTube ID  start seconds                    label train/test split  \
# 0       ---g-f_I2yQ              1          people marching             test
# 36      --U7joUcTCo              0          people coughing             test
# 52      --i-y1v8Hy8              0           female singing             test
# 78      -0BIyqJj9ZU             30    people belly laughing             test
# 117     -0jeONf82dE             21           horse neighing             test
# ...             ...            ...                      ...              ...
# 199413  zz0fdUGTHWo             45  chimpanzee pant-hooting             test
# 199425  zzFdhaiG_Hk             95          popping popcorn             test
# 199441  zzbTaK7CXJY             30               wind noise             test
# 199458  zzqrZOq928w             55            train horning             test
# 199464  zzvCPtdNxNo             68      civil defense siren             test
#
#            idx                    result_file_name
# 0            0               people marching_0.wav
# 36          36              people coughing_36.wav
# 52          52               female singing_52.wav
# 78          78        people belly laughing_78.wav
# 117        117              horse neighing_117.wav
# ...        ...                                 ...
# 199413  199413  chimpanzee pant-hooting_199413.wav
# 199425  199425          popping popcorn_199425.wav
# 199441  199441               wind noise_199441.wav
# 199458  199458            train horning_199458.wav
# 199464  199464      civil defense siren_199464.wav
#
# [13543 rows x 6 columns]

# %%
with tqdm(total=len(downloaded_data)) as pbar :
    for i, row in downloaded_data.iterrows() :
        idx = id_list.index(row["YouTube ID"])
        sttime = int(row["start seconds"])
        endtime = sttime + 10
        result_file_name = row["result_file_name"]
        #print(sttime, result_file_name)
        try :
            sound = AudioSegment.from_mp3(
                mp3_name_list[idx]
            )[int(sttime) * 1000:int(endtime) * 1000].export(
                os.path.join(VGGSOUND_DATASET_PATH, result_file_name)
            )
        except Exception as e:
            print(e)

        pbar.update(1)
# Out:
#   0%|          | 0/13543 [00:00<?, ?it/s]
