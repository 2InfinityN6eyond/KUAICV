# %% [markdown]
# # notebook contains code and comment for downloading vggset dataset, re-download missing downloads, postprocess raw audio files

# %%
import os
from glob import glob
from tqdm.notebook import tqdm
import pandas as pd
import json

#import youtube_dl
import yt_dlp as youtube_dl
import librosa
from pydub import AudioSegment

import concurrent.futures 
import threading

# %%
AUDIOSET_DATASET_PATH = "./audioset/"
MP3_FILE_ROOT_PATH = "./audioset_tmp"
AUDIOSET_METADATA_PATH = "./audioset_meta_data.json"

audioset_data = pd.read_csv(
    "./eval_segments.csv",
    delimiter=', ',
    skiprows = [0, 1, 2],
    names = ["vid", "stt", "ett", "label"]
)

with open(AUDIOSET_METADATA_PATH, "r") as fp :
    audioset_meta_data = json.load(fp)    

audioset_data
# Out:
# /tmp/ipykernel_1060092/2525048367.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   audioset_data = pd.read_csv(
#                vid    stt    ett                                      label
# 0      --4gqARaEJE    0.0   10.0    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"
# 1      --BfvyPmVMo   20.0   30.0                                 "/m/03l9g"
# 2      --U7joUcTCo    0.0   10.0                                "/m/01b_21"
# 3      --i-y1v8Hy8    0.0    9.0  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"
# 4      -0BIyqJj9ZU   30.0   40.0         "/m/07rgt08,/m/07sq110,/t/dd00001"
# ...            ...    ...    ...                                        ...
# 20366  zyF8TGSRvns  150.0  160.0   "/m/0dwsp,/m/0dwtp,/m/0f8s22,/m/0j45pbj"
# 20367  zz35Va7tYmA   30.0   40.0  "/m/012f08,/m/07q2z82,/m/07qmpdm,/m/0k4j"
# 20368  zzD_oVgzKMc   30.0   40.0                               "/m/07pn_8q"
# 20369  zzNdwF40ID8   70.0   80.0                        "/m/04rlf,/m/0790c"
# 20370  zzbTaK7CXJY   30.0   40.0         "/m/03m9d0z,/m/07qwyj0,/t/dd00092"
#
# [20371 rows x 4 columns]

# %% [markdown]
# ## set yt_dlp options

# %%
ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '320',
    }],
    'outtmpl': os.path.join(MP3_FILE_ROOT_PATH, "%(id)s.%(ext)s"),
    'quiet':True,
    'external_downloader_args': ['-loglevel', 'panic']
}
slink = "https://www.youtube.com/watch?v="

audioset_data["idx"] = range(len(audioset_data))
audioset_data["url"] = slink + audioset_data["vid"]

audioset_data
# Out:
#                vid    stt    ett                                      label  \
# 0      --4gqARaEJE    0.0   10.0    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"
# 1      --BfvyPmVMo   20.0   30.0                                 "/m/03l9g"
# 2      --U7joUcTCo    0.0   10.0                                "/m/01b_21"
# 3      --i-y1v8Hy8    0.0    9.0  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"
# 4      -0BIyqJj9ZU   30.0   40.0         "/m/07rgt08,/m/07sq110,/t/dd00001"
# ...            ...    ...    ...                                        ...
# 20366  zyF8TGSRvns  150.0  160.0   "/m/0dwsp,/m/0dwtp,/m/0f8s22,/m/0j45pbj"
# 20367  zz35Va7tYmA   30.0   40.0  "/m/012f08,/m/07q2z82,/m/07qmpdm,/m/0k4j"
# 20368  zzD_oVgzKMc   30.0   40.0                               "/m/07pn_8q"
# 20369  zzNdwF40ID8   70.0   80.0                        "/m/04rlf,/m/0790c"
# 20370  zzbTaK7CXJY   30.0   40.0         "/m/03m9d0z,/m/07qwyj0,/t/dd00092"
#
#          idx                                          url
# 0          0  https://www.youtube.com/watch?v=--4gqARaEJE
# 1          1  https://www.youtube.com/watch?v=--BfvyPmVMo
# 2          2  https://www.youtube.com/watch?v=--U7joUcTCo
# 3          3  https://www.youtube.com/watch?v=--i-y1v8Hy8
# 4          4  https://www.youtube.com/watch?v=-0BIyqJj9ZU
# ...      ...                                          ...
# 20366  20366  https://www.youtube.com/watch?v=zyF8TGSRvns
# 20367  20367  https://www.youtube.com/watch?v=zz35Va7tYmA
# 20368  20368  https://www.youtube.com/watch?v=zzD_oVgzKMc
# 20369  20369  https://www.youtube.com/watch?v=zzNdwF40ID8
# 20370  20370  https://www.youtube.com/watch?v=zzbTaK7CXJY
#
# [20371 rows x 6 columns]

# %% [markdown]
# ## define function for download raw audio

# %%
def download_video(url, opt) :
    with youtube_dl.YoutubeDL(opt) as ydl :
        try :
            ydl.download([url])
            return {"url": url, "status":True}
        except Exception as e :
            return {"url": url, "status":False, "error": str(e)}

def download_parallel(url_list, opt, max_workers = 10) :
    log_data = []
    
    with concurrent.futures.ThreadPoolExecutor(
        max_workers = max_workers
    ) as executor :
        future_to_url = {
            executor.submit(
                download_video, url, opt
            ) : url for url in url_list
        }
        for future in tqdm(
            concurrent.futures.as_completed(future_to_url),
            total = len(url_list)
        ) :
            url = future_to_url[future]
            result = future.result()
            log_data.append(result)

    return log_data

# %% [markdown]
# ## download audios parellely and save result metadata

# %%
_ = '''
# do this work using python file. ipython notebook is not suitable for this task.
results = download_parallel(
    audioset_data["url"][:100], ydl_opts, max_workers = 10
)

with open(AUDIOSET_METADATA_PATH, "w") as fp :
    json.dump(
        results, fp
    )
'''

# %% [markdown]
# # re-download missing audio

# %%
with open(AUDIOSET_METADATA_PATH, "r") as fp :
    data=json.load(fp)

redownload_video_list = list(filter(
    lambda record : record["status"] == False and "errno 2" in record["error"],
    data
))


print("videos to re-download :")
print(redownload_video_list)

print("downloading..")
results = download_parallel(
    list(map(
        lambda record : record["url"],
        redownload_video_list
    )),
    ydl_opts,
    max_workers = 50
)


for r1 in results :
     for r2 in data :
          if r1["url"] == r2["url"] :
               data.remove(r2)
               data.append(r1)
# Out:
# videos to re-download :
# []
# downloading..
# 0it [00:00, ?it/s]

# %% [markdown]
# ## postprocess

# %%
mp3_name_list = glob(os.path.join(MP3_FILE_ROOT_PATH, "*"))

id_list = sorted(list(map(
    lambda x :  os.path.basename(x).split('.')[0],
    mp3_name_list
)))

id_list
# Out:
# ['--4gqARaEJE',
#  '--BfvyPmVMo',
#  '--U7joUcTCo',
#  '--i-y1v8Hy8',
#  '-0BIyqJj9ZU',
#  '-0CamVQdP_Y',
#  '-0Gj8-vB1q4',
#  '-0Gj8-vB1q4',
#  '-0RWZT-miFs',
#  '-0jeONf82dE',
#  '-0nqfRcnAYE',
#  '-0nqfRcnAYE',
#  '-0p7hKXZ1ww',
#  '-0vPFx-wRRI',
#  '-0xzrMun0Rs',
#  '-0yRK50zyTI',
#  '-116CjQ3MAg',
#  '-1EXhfqLLwQ',
#  '-1Hub6Ps_cc',
#  '-1LQP2wemiQ',
#  '-1OlgJWehn8',
#  '-1PZQg5Gi8A',
#  '-1UWSisR2zo',
#  '-1hDIl9Udkw',
#  '-1hDIl9Udkw',
#  '-1nilez17Dg',
#  '-1nilez17Dg',
#  '-1pRmoJIGQc',
#  '-21_SXelVNo',
#  '-22tna7KHzI',
#  '-2EKWgTNEYU',
#  '-2sE5CH8Wb8',
#  '-2xiZDEuHd8',
#  '-3-4qmWSJXU',
#  '-36qTeAdDMI',
#  '-3Kv4fdm7Uk',
#  '-3YWuPXHknk',
#  '-3nXxwBlX5A',
#  '-3nyUrKWFEE',
#  '-3rHVsIj1M8',
#  '-3z5mFRgbxc',
#  '-47nPCeukVc',
#  '-4SYC2YgzL8',
#  '-4SYC2YgzL8',
#  '-4kkGS4-qVM',
#  '-4kkGS4-qVM',
#  '-4pmCrSdMhg',
#  '-4viN_EoxOA',
#  '-53zl3bPmpM',
#  '-5CGQGSFGyg',
#  '-5FoeegAgvU',
#  '-5FoeegAgvU',
#  '-5PZ_Bh-M6o',
#  '-5PZ_Bh-M6o',
#  '-65CfQUX9Ng',
#  '-6Aq2fJwlgU',
#  '-6GcdDStIwM',
#  '-6HBGg1cAI0',
#  '-6JnAxTXApw',
#  '-6cTEqIcics',
#  '-7B9tPuIP-w',
#  '-7B9tPuIP-w',
#  '-7IhwezUrUA',
#  '-7TanrCbmME',
#  '-7YESdyyHVw',
#  '-7eDqv-6AKQ',
#  '-7eDqv-6AKQ',
#  '-7vpNApSN8g',
#  '-88me9bBzrk',
#  '-8C-gydUbR8',
#  '-8Ds_ZrtQ9M',
#  '-8Mzg0pjOzc',
#  '-8cgbhIR_pw',
#  '-8pCMgGKZY8',
#  '-8s8gqSkRzI',
#  '-95a1RB0jHs',
#  '-98gqe2LWcg',
#  '-9O1cb8z7Mk',
#  '-9mHz0OsKKw',
#  '-9mHz0OsKKw',
#  '-9phJ0sJrXg',
#  '-A-Un_X21lU',
#  '-A-Un_X21lU',
#  '-A1o1Egi20c',
#  '-A3zsFeU_OI',
#  '-ABOfhcXwt8',
#  '-ANxUxvGASw',
#  '-ANxUxvGASw',
#  '-AeiYb4vDK0',
#  '-AeiYb4vDK0',
#  '-Am9MfJ6Z2o',
#  '-BAF0DHMqVA',
#  '-BHPu-dPmWQ',
#  '-BHPu-dPmWQ',
#  '-BWhd7Q43tE',
#  '-BWhd7Q43tE',
#  '-BY64_p-vtM',
#  '-Bu7YaslRW0',
#  '-Bu7YaslRW0',
#  '-Bx_-I7sB5k',
#  '-Bx_-I7sB5k',
#  '-By6I234TSs',
#  '-By6I234TSs',
#  '-ByoSbgzr4M',
#  '-COelgvUEW4',
#  '-CXICIHCb6Y',
#  '-CZ1LIc8aos',
#  '-Cr0wim-lIQ',
#  '-D--GWwca0g',
#  '-DSNfC2EJhU',
#  '-DnZ_ZY3lgA',
#  '-E35OMfL4A4',
#  '-EVRXQpt1-8',
#  '-EdnWQqlerc',
#  '-EgyhJoKuRU',
#  '-F7sBonFvVw',
#  '-FITRqeXl9Q',
#  '-FKrYTj_eCU',
#  '-FoTxwPOz3U',
#  '-Fy2i3zpYdY',
#  '-G04QpzSpbU',
#  '-G3tJhsHtKU',
#  '-GVRoRILVD4',
#  '-Gf4Ihv1zwc',
#  '-Gr9P8Abnlk',
#  '-HAoExLVs6Q',
#  '-HKAgW-vzSI',
#  '-HKAgW-vzSI',
#  '-IKnJa9U66I',
#  '-IVxwkTcpp4',
#  '-IZbvEO9wzU',
#  '-IeSZuZNhPw',
#  '-IeSZuZNhPw',
#  '-Igq1W20Gi8',
#  '-Irh7_N5Kjs',
#  '-JBH9j7-h8U',
#  '-JJmkQYZA-4',
#  '-JUBdOr8Hes',
#  '-JeVsIKuMIM',
#  '-JeVsIKuMIM',
#  '-JlIkV1f_g4',
#  '-JvB5AL59fM',
#  '-K1BRF6qng8',
#  '-KA76yUSK44',
#  '-KTabIWnPSg',
#  '-LRl10YdS-U',
#  '-LU2f6iVRVg',
#  '-M6K3QoHh40',
#  '-M7ZNV6gLo0',
#  '-M7sMIJRQgg',
#  '-MaA9JUGSBI',
#  '-MwKGVrPrmA',
#  '-NRx0SBMjo0',
#  '-Nc_T1FvPx0',
#  '-NrseuJrJ6k',
#  '-OAyRsvFGgc',
#  '-OMB-w3LPNY',
#  '-OUIEnuNd1I',
#  '-OVb-UG8yJw',
#  '-Opbeu2Y2yg',
#  '-OytVyTEboM',
#  '-PVEno65928',
#  '-PyXfNxnHKs',
#  '-Q9MTRXS4bE',
#  '-QX2Gv7J5gY',
#  '-Q_UXiwWR_c',
#  '-QsPqh8Kyrc',
#  '-QuWdnmn-kM',
#  '-R8MAtu1vWY',
#  '-RBs9pPhHY8',
#  '-RKQEJbjXx0',
#  '-RLILmQmubM',
#  '-RYtUAsNhF0',
#  '-S-TDT5oq0Q',
#  '-S1mCXpSsvc',
#  '-SD43H5B5hE',
#  '-SWaCArvQug',
#  '-Sd-j0rKeKw',
#  '-SmkiYKIhfs',
#  '-StCvzCSVdA',
#  '-T2MO0xBNwM',
#  '-T3Td30k7hA',
#  '-TN-8OnbpPQ',
#  '-U16iKiXGuY',
#  '-U7agd00tIg',
#  '-U9jfwt03Gg',
#  '-UKH_6moRZc',
#  '-UTdhK0lwuw',
#  '-Umconw-CRE',
#  '-UoPcgmbIkk',
#  '-VLOm8cJZRI',
#  '-VasGrFLqW8',
#  '-Vo4CAMX26U',
#  '-Vt__PL1bgk',
#  '-WDOQunQq5Q',
#  '-WGiNsWOczo',
#  '-WXIhTodJ6M',
#  '-Wd5YV97ftU',
#  '-WoudI3gGvk',
#  '-WvVG0wHcTc',
#  '-X8J0l_ISNI',
#  '-XZBpMKRhok',
#  '-XilaFMUwng',
#  '-XnPjiPiRAM',
#  '-XwtCzUaN1I',
#  '-XxUW9gW6mc',
#  '-Y8sJDoL1YA',
#  '-YAyjUL7_xo',
#  '-YIT4HBM__g',
#  '-YRJHtktT1g',
#  '-YfaQljuwwA',
#  '-Yk2eyBxCdQ',
#  '-YwPSwhe2jo',
#  '-Z1ZSWDouUU',
#  '-Z8bjo6q6jc',
#  '-ZFQfWBmfdE',
#  '-ZJqu_4zLMc',
#  '-ZlExzZRlF4',
#  '-_9xozPeXzk',
#  '-_HXiz8XnV0',
#  '-_QPd-VskKY',
#  '-_UCboMO_xE',
#  '-_f_ClsDxyc',
#  '-a0drwQsrso',
#  '-a8dC-A_xQE',
#  '-aJYgmhyrvQ',
#  '-aOxR6ILsw8',
#  '-aRZT0PYhJU',
#  '-aXWYfAdovc',
#  '-adm_P3xa0s',
#  '-bGQrd947QE',
#  '-bJPDtT31p0',
#  '-bNJ9olw-OE',
#  '-bZ4yrpTcjw',
#  '-bgHkxwoliw',
#  '-c7hCWwTlrY',
#  '-cA9HsnV1ao',
#  '-cj4S5lJmYE',
#  '-ct58kOlLfs',
#  '-dL27atcAig',
#  '-dL_J5KkKZQ',
#  '-dVgUSrR8g4',
#  '-e4wXAy1iVo',
#  '-eDAoheZrY8',
#  '-eK9VHuiH74',
#  '-eabL1vJMt0',
#  '-f1DNyngKVY',
#  '-f6s6kQEHFY',
#  '-fAGzY9rnaA',
#  '-fJsZm3YRc0',
#  '-fPdOa99Iwg',
#  '-fTfRh0_RQ4',
#  '-fz6omiAhZ8',
#  '-gAzofSmRiY',
#  '-gBOhfAyaGI',
#  '-gCqnkIUmp0',
#  '-gKMeeAk460',
#  '-gSfPQqi6nI',
#  '-gbWL7MJ_kI',
#  '-geVmY-Zo3E',
#  '-gz_moHFwl4',
#  '-h5ZGw9Ci5c',
#  '-hA3ZkfDz30',
#  '-hJ1YTZ5AGI',
#  '-hSMzrWZCAE',
#  '-hYRFCQdbLg',
#  '-hedbpc8T0E',
#  '-hfAbHHlj44',
#  '-hn5Sfg7kX0',
#  '-hss7xpzIVc',
#  '-i9gpG3vPwA',
#  '-i9uQMysy_A',
#  '-inB65exXFU',
#  '-izmQQrgmsQ',
#  '-jA7nRwQp_E',
#  '-jFSYIHh6zc',
#  '-jLujkP1aaw',
#  '-jZENGDFArw',
#  '-jaY3LS3Dv0',
#  '-jcBFqcdpuI',
#  '-ji1W2uf7iM',
#  '-k-hxP5eWko',
#  '-kE7IL6pnKU',
#  '-kPDH9n0PG4',
#  '-kS4J9hxMLQ',
#  '-kWlE2dkoxc',
#  '-kZVoaYYU6o',
#  '-kpR93atgd8',
#  '-l-E3kyNcag',
#  '-lJctvybAJ8',
#  '-lK7eYXq2ZQ',
#  '-lPXTBXa0tE',
#  '-lU8pMETgCM',
#  '-lcKnmO7gfo',
#  '-lci0RRFlkA',
#  '-ltdnlF_qMU',
#  '-m9pH0WXQto',
#  '-mKtgDnG0oM',
#  '-mN6UH1Gd40',
#  '-mmJqfAGvGs',
#  '-mpapCZXors',
#  '-mt3Oo7t3aw',
#  '-n53K1XWaMc',
#  '-nDPmlHReow',
#  '-nJbGyPg6BY',
#  '-nQ9a0P1TlY',
#  '-na-0NBG5Ow',
#  '-nlkWWphiaM',
#  '-nv4LwXRnCg',
#  '-o4TvhpbeTY',
#  '-oC3FVOx62g',
#  '-oCfYDEa8EE',
#  '-oGJwGEsIiA',
#  '-oSzD8P2BtU',
#  '-ocADGlyaHc',
#  '-p-pVVp0Ibo',
#  '-pBFsYisTCM',
#  '-pDS3yN4B1s',
#  '-pUfYFcsgG4',
#  '-q56v8eoD2I',
#  '-q6f1XIGuL4',
#  '-qBctCzLI5s',
#  '-qS77R0Y1K8',
#  '-q_bj2uHkWc',
#  '-qcTD2o6I9s',
#  '-qfsR2ZEUcw',
#  '-qpgeVTesdE',
#  '-qtYcqvW_oc',
#  '-qxw8nbLj_0',
#  '-r2-9oyIzkQ',
#  '-rb6uia1wSo',
#  '-rj9TENwPzQ',
#  '-s5ZidRvnjQ',
#  '-s8GfWT7_I0',
#  '-sEh3pYmT1E',
#  '-sevczF5etI',
#  '-spqqACI6UQ',
#  '-suGlxVxdCM',
#  '-t-htrAtNvM',
#  '-tBM2ZfncoU',
#  '-tKZOl4q1Kw',
#  '-taO6N-rxv4',
#  '-toIkHblwZU',
#  '-tpq_bzSKes',
#  '-uGHAvfqs2I',
#  '-uaTK8sa5Ms',
#  '-vBj0PZ1RF0',
#  '-vRhQeleXzE',
#  '-vZ-_4oFCzs',
#  '-vg8ttgP32I',
#  '-w12aSkQ9No',
#  '-w8maIWtnUk',
#  '-wHOJSFITTg',
#  '-wQ8El8J_dE',
#  '-wiXdIMwM-I',
#  '-wnDAPcoPsk',
#  '-wwmAy7sUrM',
#  '-wymN80CiYU',
#  '-xQbyezhw_k',
#  '-xfgovG6-KU',
#  '-xuq3kOwGGw',
#  '-yTHDQZL1dE',
#  '-yc2dgZAkgM',
#  '-yrutqBKk-U',
#  '-z3n74RK92U',
#  '-z4OZ7ls5Bo',
#  '-zCtwbk005g',
#  '-zI7FN8cMIE',
#  '-zNEcuo28oE',
#  '-znnr5EbiAc',
#  '0-2Onbywljo',
#  '0-6N0Qagy5A',
#  '0-7PyzhzuYQ',
#  '0-EgET9q3qE',
#  '0-N62G9etNE',
#  '0-ljtP6WJrI',
#  '0-o0oZvSFOk',
#  '0-yskgO46Bg',
#  '007P6bFgRCU',
#  '00AGIhlv-w0',
#  '00FBAdjlF4g',
#  '00G2vNrTnCc',
#  '00KM53yZi2A',
#  '00XaUxjGuX8',
#  '00cREXaIlnQ',
#  '00iiNF4tn4o',
#  '00vYncpl0pk',
#  '00wORCOKNHw',
#  '00z0M1DJyAw',
#  '01CiQ6VDxbo',
#  '01SaXyGY5SM',
#  '01he_d18c8o',
#  '01x0zZpL87I',
#  '02-0m4RbDUI',
#  '02Ak1eIyj3M',
#  '02Fdq2tyIWI',
#  '02UvvE1oA1I',
#  '02XbmweOzOY',
#  '03IZHwOh2eQ',
#  '03Q2SbeP_cw',
#  '03Uz8L0u07Q',
#  '03aJ_RcnBko',
#  '03c-hmoUfuc',
#  '03c2pnO2Xv0',
#  '03zeVlBWhdY',
#  '0439dMJj-FY',
#  '043ltTrTSno',
#  '0474eRAlFLY',
#  '04ChQ0fqzxQ',
#  '04NjXsLyCl4',
#  '04QV0Xi5YTk',
#  '04xLK7R5wNA',
#  '054iiUoKoyo',
#  '055kC3FYxK0',
#  '05JAmKFVy44',
#  '05rzRNMhoL0',
#  '06Nq51sogmQ',
#  '06pzMwo6VHA',
#  '06rCpqwkcDw',
#  '076qdKSC8nU',
#  '07AQUF6A_mg',
#  '07FxCXxknY4',
#  '07I7v5ISD7Y',
#  '07mCK08xGRc',
#  '07rwFurzpw8',
#  '07xGXxIHOL4',
#  '08Cm_RuvHmk',
#  '08QQAMaw24E',
#  '08Ua8a01P5g',
#  '08mf5GxT820',
#  '08wKt83tR5E',
#  '08wOPt-2PeE',
#  '097K1uMIPyQ',
#  '098xwjCQmHc',
#  '09kqMqn5rWs',
#  '09lQmg2wvsY',
#  '09pZj6CEvRw',
#  '09rHHvq75-U',
#  '0A-VisU1k8U',
#  '0AA0R8gbxcI',
#  '0ARh-9Amrv0',
#  '0AkRWunFZPk',
#  '0AqnCSdkjQ0',
#  '0B7fwvTtvLM',
#  '0BCXcbaLeoA',
#  '0BauNGmZtTU',
#  '0BgI0XxW0kE',
#  '0BlmXxLck5g',
#  '0CA5CPHRXDc',
#  '0CJFt950vOk',
#  '0CTgEP0SIVg',
#  '0Cd8q2Zg1Mc',
#  '0Cl6hXpryhY',
#  '0Cu33yBwAPg',
#  '0CzC0-cXe8M',
#  '0D9ZiiYArKw',
#  '0DJP7ywh7nc',
#  '0DizopdPMBw',
#  '0DwRfesDQvE',
#  '0DzsPL-xElE',
#  '0EI7FxbdsUE',
#  '0EOQco76eXQ',
#  '0EQYTfW7TDc',
#  '0EiQyHjoaz8',
#  '0EvpBtracsk',
#  '0EyIdGgbPEo',
#  '0EyJ15KLxg4',
#  '0F-Z0zF1504',
#  '0F04c_rY4aw',
#  '0FjrveIENzI',
#  '0Fzrv1GXHPI',
#  '0G50t4FlbIA',
#  '0GFtqzOWnWg',
#  '0GNNFBrRz1E',
#  '0Ga7T-2e490',
#  '0GhmrpFuRNQ',
#  '0Gxn9FtaJFc',
#  '0H25ve3qts4',
#  '0H30ORfaFK8',
#  '0H814XXq-WQ',
#  '0HGsAx2KjPM',
#  '0HXYdGGKV2k',
#  '0HbhE91JB-k',
#  '0HqZRxHCGLc',
#  '0HzbpwB3xDk',
#  '0ISHZQJdeSw',
#  '0ImJuPpEpco',
#  '0IwGsEzITQs',
#  '0IxyUtHw6Ec',
#  '0IzhjqyDzt8',
#  '0J3wJhQVOII',
#  '0J_TdiZ3TKA',
#  '0JbGxIR8JTk',
#  '0JjprYD2Yhw',
#  '0Jq6WJLLSIk',
#  '0K0pXiZrUJA',
#  '0KCVgexi4yU',
#  '0KKTw8pfNjg',
#  '0KOPvSUlNjI',
#  '0L2ndtt60Q8',
#  '0LAcf9DNd1Q',
#  '0LE6Ll1rVlg',
#  '0LLlcPiatiU',
#  '0LTmV_dOmmo',
#  '0LY5zuRlIac',
#  '0MEPG8c0jqk',
#  '0MV5mb0RJLY',
#  '0Mba3BS1oRM',
#  '0MzrXd8CUCg',
#  '0N0C0Wbe6AI',
#  '0N17tEW_WEU',
#  '0N3-lCzOQPI',
#  '0N6S5OoG7Vg',
#  '0N9EN0BEjP0',
#  '0NMnJXcrhPo',
#  '0NW8rsCj6xQ',
#  '0NZLG7HMiLg',
#  '0O-gZoirpRA',
#  '0OFlTh2_Obo',
#  '0OY8XXZ98rw',
#  '0OYlHvyfNk4',
#  '0OhqyNGlJYE',
#  '0Olm321vgk8',
#  '0PHUQku2P5I',
#  '0PKdFG3iB8w',
#  '0PMFAO4TIU4',
#  '0PQYNtIBVf4',
#  '0QSPtpp1HN8',
#  '0QTme5iyg4A',
#  '0QYedLfOwcI',
#  '0QabiRBcEKc',
#  '0QdEYUt4LL8',
#  '0QqQ1j1vBgw',
#  '0R6KIVvlyfQ',
#  '0R85JknaH-w',
#  '0RMYLychMXc',
#  '0RZRFj7zDnQ',
#  '0RcMzUdXDRQ',
#  '0Rg7tKJWk2w',
#  '0RgGrVklaao',
#  '0Rjyih3W0Is',
#  '0Rp0mQTZF2o',
#  '0Rt6sNb3P8o',
#  '0RyzdrZgrus',
#  '0S2mvjzH_xQ',
#  '0SLv6CmZas8',
#  '0SNhAKyXtC8',
#  '0SnjS2w_c80',
#  '0TKyCw1Ykq8',
#  '0TV9zvfwFhs',
#  '0TiEO149Ydc',
#  '0TvuLbDrd6g',
#  '0U20V7Kh_kc',
#  '0U7mQ5GYMX8',
#  '0U9_6RyH3_M',
#  '0UF1FHDPM1A',
#  '0Ubu4BqSWmU',
#  '0V7-w8K3Fgw',
#  '0VCK8rLKXKA',
#  '0VjPCd62oKg',
#  '0VnKeRijmM8',
#  '0W1sNicXboU',
#  '0Wkk9iNzA9c',
#  '0XFFOBzJ3aw',
#  '0XSNrKgA94g',
#  '0XTWdzBttaU',
#  '0Xe2zCJNjvk',
#  '0XeH2s-LzZE',
#  '0XxinBtKouQ',
#  '0YIWrXgCjiM',
#  '0YI_WYJVv2M',
#  '0YTieIiZNN4',
#  '0Ycad70UNwE',
#  '0YsC6M4GFoc',
#  '0ZAfYE4bgs8',
#  '0ZN2HKsFg4A',
#  '0_1BfYtffzg',
#  '0_8-g2rof7E',
#  '0_B2YnBAz3A',
#  '0_FFqLukmHk',
#  '0_O6nVfnCH8',
#  '0_XItMAYkwc',
#  '0_gci63CtFY',
#  '0a5KHX_odJ8',
#  '0a91szM1Ivw',
#  '0aYAf-S-fKM',
#  '0aaLWD7TUSU',
#  '0abzD7hBTRk',
#  '0bKpv6YBl7g',
#  '0bO6DhC2tlU',
#  '0bP2MH3LqvI',
#  '0bRUkLsttto',
#  '0bWZNWZ8YCI',
#  '0bhY7v5dJDY',
#  '0bsbkdnSgMQ',
#  '0bvPjMQ_WbE',
#  '0c1YU_VtFRE',
#  '0c78GAZ0jLY',
#  '0cNYPgD6cEA',
#  '0cZQm65sZjc',
#  '0crG6jzAUpE',
#  '0dC6Ay0oqWk',
#  '0dPx94RPy2M',
#  '0dVmGVa3Rbw',
#  '0dgl6Rvt3X0',
#  '0eTrzI5-ong',
#  '0eXXRhp0p3w',
#  '0ewQiU3q5jM',
#  '0fCpAuxrQ_I',
#  '0fD-eSRrybM',
#  '0fZKF6FprcA',
#  '0fiOM---7QI',
#  '0foC-4n-eH0',
#  '0fsntL6RKww',
#  '0fvq8YY28qI',
#  '0fwt2zSftIc',
#  '0g-KosNgMYA',
#  '0g4SlqjORM4',
#  '0g_-KI5NZ-E',
#  '0hOD_iIeePk',
#  '0hUft9scxzY',
#  '0hWIKYNSEPE',
#  '0he6VV5Y9Bg',
#  '0hfU27A6tus',
#  '0hjqlmdPT6g',
#  '0i-RTS_FXcM',
#  '0i8VM_EooCs',
#  '0iiwZ2_9Vi8',
#  '0izHOfrwPn4',
#  '0jFQ21A6GRA',
#  '0jR20-0sy1Y',
#  '0j_nQcD7jdU',
#  '0jiu0RNizU8',
#  '0jnvb2H25_Q',
#  '0jy-sVREk4o',
#  '0k6KjLouAHs',
#  '0kIIGL-xFhY',
#  '0kNCB0oGiL4',
#  '0kQD1P0_KUs',
#  '0kQjfwXjFuY',
#  '0kY1isykrrs',
#  '0kqQNBR09Rc',
#  '0lJyHuTVMNY',
#  '0lPcHRhXlWk',
#  '0loP4WNnL2k',
#  '0m2rwP3eYno',
#  '0m9-5BkL4Mc',
#  '0mD4OcdidBM',
#  '0mNvPaqfwUI',
#  '0mXkme9abiU',
#  '0mZQ6Q-viPw',
#  '0ml1KwECOo8',
#  '0noFcocWRzw',
#  '0oI0BvmTLvA',
#  '0onKcFY1Tu0',
#  '0oudYrPGNN8',
#  '0p0sM9wBLiE',
#  '0p7J0O8ew0k',
#  '0pHPUaSSEWc',
#  '0pHTgC1Frnw',
#  '0pLgOm0xgjY',
#  '0pyk5xo7XAI',
#  '0q1wOYCfLlQ',
#  '0qDs_aC0LwI',
#  '0qZ54ovyEWQ',
#  '0rNQE7fccQg',
#  '0rbUCEM20aw',
#  '0rqmPdr352Q',
#  '0rz3h0ghprk',
#  '0rzB4A1PjnA',
#  '0s0Uy0-zBa0',
#  '0s6gEV9d52I',
#  '0sE4JvKFpMI',
#  '0sPVAP17w2U',
#  '0sYXPO7lzco',
#  '0saogke2Mec',
#  '0slyl34xWug',
#  '0soVCtJgDTk',
#  '0ssOpzqkojU',
#  '0sstijfm2nM',
#  '0tgNg0MHgxc',
#  '0toUq9UHCSA',
#  '0trWdhSvab4',
#  '0u5dddSWuj8',
#  '0unBNMBYhwQ',
#  '0vFPs6XsU_Q',
#  '0vSmiq7CrCk',
#  '0vXqf9ix8LE',
#  '0vg9qxNKXOw',
#  '0w7pCxwXzVc',
#  '0wM_qR6Yihk',
#  '0wYi8B9PXDY',
#  '0wgqpjfTmJI',
#  '0wp4JNMogzQ',
#  '0wzsE67O5tE',
#  '0x82_HySIVU',
#  '0x9TnOQ5Nhw',
#  '0xGoUJpt6eQ',
#  '0xm_4yGhHjc',
#  '0yT6ihPVX54',
#  '0yTfnhm-Ny0',
#  '0ylr6p_m4p0',
#  '0yxJzCQW5zI',
#  '0zDEut-yfis',
#  '0zP9jebYSrk',
#  '0zgffMTkGtU',
#  '1-TnkdEPXEw',
#  '1-WyAvPxqDM',
#  '1-Y9kafYuqQ',
#  '1-z7wzzstMs',
#  '1009ux1xbkg',
#  '10DM6WINIS8',
#  '10V4g8MXF-Y',
#  '10YXuv9Go0E',
#  '10aBef0Ghkc',
#  '10aF24rMeu0',
#  '10eyuX_4Huo',
#  '10hGfv89L3g',
#  '10lWpHyN0Ok',
#  '10rH37YYvKU',
#  '11FeId69WOk',
#  '11KWMKfalJo',
#  '11iTkkMaUVo',
#  '11q7KkNkLFg',
#  '11ruZHgyTKM',
#  '126AbihZt28',
#  '12C-RCb6UFw',
#  '12OSBJwogFc',
#  '12T-9dLEbY8',
#  '12UFv05Qmpw',
#  '12nRM9_Q6so',
#  '13jEiCXpPIE',
#  '13oklol49ZY',
#  '13wd8KvOt58',
#  '14XML4NbS38',
#  '14hTDUjCr_g',
#  '14jcqHjMXcI',
#  '14vbVhCbKVc',
#  '154WG9Gv1I4',
#  '15Mw2jyyHk0',
#  '15mRtNj-zAU',
#  '16JM_ZgvQQ8',
#  '16TsDMjHzYU',
#  '16vy6Lz8tkY',
#  '17AtKbQ7glU',
#  '17CpJxlwzNg',
#  '17L2VkXtcQ0',
#  '17WW_p1N7BQ',
#  '17tqXgvCN0E',
#  '17wA3UyGUX8',
#  '18212B4yfLg',
#  '18HRNQyo9mg',
#  '18MCVaBd4Vc',
#  '18PLoJDIvIQ',
#  '18aaA2efGng',
#  '18avBmoYIrk',
#  '18mS4cLPOb8',
#  '18r-Vtspi8g',
#  '19_c58yNYVw',
#  '19knOj43yZE',
#  '1A4faLHDx_U',
#  '1ACn3u5UnBw',
#  '1Aokrz07aSA',
#  '1B-RuZgSqf8',
#  '1BVSYfNCcv0',
#  '1BYZiONhW3c',
#  '1CGx8zxQFx4',
#  '1CRvPsMwqrc',
#  '1CZ-bybGzu4',
#  '1D4LxbOVn1I',
#  '1D6UsaTflJ8',
#  '1DNoynuGLV4',
#  '1DS0AE3vTwA',
#  '1DWt70gTqHc',
#  '1De-OI8YG-M',
#  '1ED_uNM-KfE',
#  '1EEy-aXHzRI',
#  '1EH6atYydBc',
#  '1ENC2smc8Ig',
#  '1EWkwWXwI1g',
#  '1EZ1_l3MpWw',
#  '1EuGaYmvlXM',
#  '1F-jIu9oy6A',
#  '1F23RciUwDE',
#  '1F3_bvIT0ig',
#  '1F8hWMEtlZM',
#  '1F9zCsJyw6k',
#  '1FU5odlgLmo',
#  '1FbxStVuFYU',
#  '1FnA3w94zXI',
#  '1G4aDTUuo7g',
#  '1G6wtnmdZhE',
#  '1GFclDpGhu0',
#  '1GMWn4IxVro',
#  '1GrCbwZIbwM',
#  '1GwY2n4HIM0',
#  '1HNGJDppKG0',
#  '1HOdnni3Fl4',
#  '1HayoASR-54',
#  '1HzPf-GXyls',
#  '1I5QQBbZP8g',
#  '1ILADUzj-M0',
#  '1IQdvfm9SDY',
#  '1ISlTAGBMhs',
#  '1IlgE0S4t3E',
#  '1IrYZhVhN1s',
#  '1J-E-QqJdkg',
#  '1J4FXUMOw8k',
#  '1JHB_-LCoNA',
#  '1JSbmO1NQzk',
#  '1J_j6c2uQaM',
#  '1JpeDWbgUO8',
#  '1Jtg95iZyoQ',
#  '1KLmIS-v60U',
#  '1KXi48OobbU',
#  '1KiFXylkPpg',
#  '1KmsVHx7E2c',
#  '1KpvQAM14Ic',
#  '1L1iOYth3-E',
#  '1LA8BxMlXSY',
#  '1LTxZ2aNytc',
#  '1Lqa2jDTnns',
#  '1MRlrSLSN84',
#  '1MTKUN3uFrs',
#  '1MeeK0kD_ys',
#  '1MgcrYdYas0',
#  '1MwaXCfUvX8',
#  '1NMDi2ZmUdo',
#  '1NWxg_BnJ0A',
#  '1NkUBIl2Plw',
#  '1Ny5ZlcBlcQ',
#  '1O-WeYTRS4w',
#  '1OFDyTzUj24',
#  '1OFOElP7bqc',
#  '1ON1iLkUPp8',
#  '1OU19ANx4fg',
#  '1OpNI5DjxC0',
#  '1Oq1Z8SZNyM',
#  '1OukV4Q7o8Q',
#  '1PAb2MoavDc',
#  '1PDg2ENa7jk',
#  '1PKxdTlquCA',
#  '1PN-bfs2EhY',
#  '1PPboJuO1Ks',
#  '1PSzSTilu_s',
#  '1PZAgEP1Xhc',
#  '1Q1pDQzTW6c',
#  '1Q9DXhXMSFI',
#  '1QtsF8qkX1Y',
#  '1RW3nDRmu6k',
#  '1RhYdQnZ_hw',
#  '1RwhRTe-OKk',
#  '1SLrRllxMkU',
#  '1SfwYQ92l6Y',
#  '1SqihV_DnEg',
#  '1SvA8MMap-A',
#  '1T1RlQPE9sE',
#  '1T790GA0vkI',
#  '1TAOyk0Xgss',
#  '1TP8JyI5vHI',
#  '1Tg9VvRZN5k',
#  '1Thl21awe2g',
#  '1TxC-sdO2rY',
#  '1TyOPtg0Yfk',
#  '1Tzq_XIAMvs',
#  '1U38Q2MpYM4',
#  '1UCNBHZQNVM',
#  '1UFU5SfQOX4',
#  '1UK8f9G7kLc',
#  '1UViJ9heiak',
#  '1UXOJ3IACj4',
#  '1Ue2DkG64r8',
#  '1Uj_ulATth0',
#  '1V-rFaIWnzU',
#  '1V7ReAk9k-4',
#  '1V9CWQNZRF8',
#  '1VRZ08sblVw',
#  '1VTxnf2hZ0w',
#  '1W-KLZJwXkc',
#  '1W2FOzSXsxs',
#  '1W4p9dUBNkA',
#  '1WGmeX6CLas',
#  '1WI9921OeRc',
#  '1WKvCCz-NZU',
#  '1WlvXneu6oY',
#  '1WuGGd6NqGk',
#  '1Wy75ZQz9rg',
#  '1X0VCv-S2H8',
#  '1XO0SqsZhHU',
#  '1Xmw9VUzvLY',
#  '1Xtkou9dtyA',
#  '1YFa9CpH7Kc',
#  '1YRhxCXCM0o',
#  '1YWeSXAXwQE',
#  '1Z0G4O0lVwA',
#  '1Z4x67dhw-s',
#  '1Z8MIXXDPls',
#  '1ZEzs9zmZaU',
#  '1ZHnWpLQtyo',
#  '1ZS9EQzbAbM',
#  '1ZaxqZMs21M',
#  '1ZgXgyEJSbc',
#  '1_7BKFMJrYA',
#  '1_Q80fDGLRM',
#  '1_knvtpENoQ',
#  '1_v-Kro86Io',
#  '1a-ODBWMUAE',
#  '1aZKmCUlXrY',
#  '1aZrc1oTbIo',
#  '1a_nvi4sW64',
#  '1aigfM5Tmqk',
#  '1bIH_Qh_clk',
#  '1bKf5nrT4DQ',
#  '1bSP4wLfMpA',
#  '1bbyaXEVouE',
#  '1btWmt9io-Y',
#  '1cCg1Y7zDnM',
#  '1ceaatuz77k',
#  '1cqcTbDxsHM',
#  '1cwGW0cBdRs',
#  '1cwOR9WGLOw',
#  '1cxvg7qu0G0',
#  '1dEobByUDYo',
#  '1dH-lZ8TNLU',
#  '1doTwVszic8',
#  '1dt9eL2rmSY',
#  '1dyFP4MGkIM',
#  '1dzwFnXJ7_E',
#  '1e0_4dwF9A4',
#  '1eP5LSjyge0',
#  '1edm2kNMYZs',
#  '1f-L1M-S6RQ',
#  '1fD5B_VGkQk',
#  '1fDGejVDAHU',
#  '1fSsCqTeqYM',
#  '1g0vAT8GHt0',
#  '1g6sdWOc9k4',
#  '1g7sOtOiSRo',
#  '1g9FuuIIs84',
#  '1gDNqOQFopY',
#  '1garMoYilAY',
#  '1ghXWnSJibU',
#  '1hABzqBHh7w',
#  '1hC6crefz0s',
#  '1hIg-Lsvc7Q',
#  '1hJnxzlxnQs',
#  '1hMZbDz2KH8',
#  '1hUNSCMZi9o',
#  '1hWAOReJehw',
#  '1hba9jmspEQ',
#  '1heMbyumHAo',
#  '1hknEtsmdOc',
#  '1hoUEfsTmdE',
#  '1hwkxJOl1PY',
#  '1i1sbQOILb0',
#  '1iqVk7kMnJQ',
#  '1isuXShxzOY',
#  '1j13NdQiw8c',
#  '1j4rFfU5XKQ',
#  '1jTQsVs5iWM',
#  '1jhbNtCWC9w',
#  '1jq7zSF_v7s',
#  '1kUeturqXOE',
#  '1kcjIUL51AI',
#  '1kkWt3ktlBA',
#  '1lCus68cAOc',
#  '1lIMpk5-2Oc',
#  '1lLobOtsIFA',
#  '1lgqqW5TsJk',
#  '1mfghenMj_E',
#  '1nGKDBEh3rs',
#  '1nKxptqHGyY',
#  '1nNXaI04SEg',
#  '1nUqhH8bAPk',
#  '1n_s2Gb5R1Q',
#  '1nbCJJtsruI',
#  '1nd-4Deqkro',
#  '1o5tdZT6kw8',
#  '1oHVE6DeIlc',
#  '1oJAVJPX0YY',
#  '1owKdIYYYeg',
#  '1p9rsIR1ezk',
#  '1pR0SgbqP3M',
#  '1pViEqMXJH0',
#  '1q8kkQhS97g',
#  '1rJIR1G1OnY',
#  '1rJWW_KqeAw',
#  '1rhsnmWLeGw',
#  '1rpGmbCIBqs',
#  '1rtXsGC-q3Q',
#  '1s-oXryGnCw',
#  '1s8ErA1OMTw',
#  '1sBp9KhJbp4',
#  '1sdKPEwPtrg',
#  '1ssmAAcX5u8',
#  '1tBzq-7MUJU',
#  '1tC7bTilFWk',
#  '1tNkAc29aPE',
#  '1tQQMIQrSPo',
#  '1tjJmArxVBM',
#  ...]

# %%
label_data = pd.read_csv("./class_labels_indices.csv")
label_dict = dict(
    zip(label_data["mid"], label_data["display_name"])
)

# %%
audioset_data = pd.read_csv(
    "./eval_segments.csv",
    delimiter=', ',
    skiprows = [0, 1, 2],
    names = ["vid", "stt", "ett", "label"]
)
audioset_data["idx"] = list(map(
    str,
    range(len(audioset_data))
))

class_list = []
for k, row in audioset_data.iterrows() :
    #print(row["label"])
    labels = row["label"][1:-1].split(',')  
    #aprint(labels)
    classes = list(map(
        lambda l : label_dict[l],
        labels
    ))
    cls = ',,'.join(classes)
    #print(cls)

    class_list.append(cls)

audioset_data["class"] = class_list


audioset_data["result_file_name"] = audioset_data["class"] + '_' + audioset_data["idx"] + ".wav"

#audioset_data["class"] = audioset_data["label"].map(label_dict)

downloaded_data = audioset_data[audioset_data['vid'].isin(id_list)]
downloaded_data
# Out:
# /tmp/ipykernel_1060092/583777003.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   audioset_data = pd.read_csv(
#                vid    stt    ett                                      label  \
# 0      --4gqARaEJE    0.0   10.0    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"
# 1      --BfvyPmVMo   20.0   30.0                                 "/m/03l9g"
# 2      --U7joUcTCo    0.0   10.0                                "/m/01b_21"
# 3      --i-y1v8Hy8    0.0    9.0  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"
# 4      -0BIyqJj9ZU   30.0   40.0         "/m/07rgt08,/m/07sq110,/t/dd00001"
# ...            ...    ...    ...                                        ...
# 20364  zxuey_Zi0wY   30.0   40.0                         "/m/085jw,/m/0mkg"
# 20366  zyF8TGSRvns  150.0  160.0   "/m/0dwsp,/m/0dwtp,/m/0f8s22,/m/0j45pbj"
# 20367  zz35Va7tYmA   30.0   40.0  "/m/012f08,/m/07q2z82,/m/07qmpdm,/m/0k4j"
# 20369  zzNdwF40ID8   70.0   80.0                        "/m/04rlf,/m/0790c"
# 20370  zzbTaK7CXJY   30.0   40.0         "/m/03m9d0z,/m/07qwyj0,/t/dd00092"
#
#          idx                                              class  \
# 0          0        Domestic animals, pets,,Squeak,,Dog,,Animal
# 1          1                                             Hammer
# 2          2                                              Cough
# 3          3       Music,,Speech,,Female singing,,Child singing
# 4          4       Chuckle, chortle,,Belly laugh,,Baby laughter
# ...      ...                                                ...
# 20364  20364    Wind instrument, woodwind instrument,,Accordion
# 20366  20366  Marimba, xylophone,,Glockenspiel,,Chime,,Malle...
# 20367  20367  Motor vehicle (road),,Accelerating, revving, v...
# 20369  20369                                       Music,,Sonar
# 20370  20370              Wind,,Rustle,,Wind noise (microphone)
#
#                                         result_file_name
# 0      Domestic animals, pets,,Squeak,,Dog,,Animal_0.wav
# 1                                           Hammer_1.wav
# 2                                            Cough_2.wav
# 3      Music,,Speech,,Female singing,,Child singing_3...
# 4      Chuckle, chortle,,Belly laugh,,Baby laughter_4...
# ...                                                  ...
# 20364  Wind instrument, woodwind instrument,,Accordio...
# 20366  Marimba, xylophone,,Glockenspiel,,Chime,,Malle...
# 20367  Motor vehicle (road),,Accelerating, revving, v...
# 20369                             Music,,Sonar_20369.wav
# 20370    Wind,,Rustle,,Wind noise (microphone)_20370.wav
#
# [17049 rows x 7 columns]

# %%
with tqdm(total = len(downloaded_data)) as pbar :
    for i, row in downloaded_data.iterrows() :

        vid = row["vid"]
        sttime = int(row["stt"])
        idx = row["idx"]
        result_file_name = row["result_file_name"]
        AudioSegment.from_mp3(
            os.path.join(MP3_FILE_ROOT_PATH, f"{row['vid']}.mp3"),
        )[sttime*1000 : (sttime + 10)*1000].export(
            os.path.join(AUDIOSET_DATASET_PATH, result_file_name)
        )
    
        pbar.update(1)
# Out:
#   0%|          | 0/17049 [00:00<?, ?it/s]

# %%
len(glob("./audioset_tmp/*"))
# Out:
# 17047

# %%
len(glob("./vggsound_tmp/*"))
# Out:
# 13017
